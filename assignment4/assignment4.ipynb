# %%
import pandas as pd
pf = pd.read_csv('./panel_fin.csv')
#pf = pf[pf['Quarter']>80]
pf[pf['l_ret']=='.']['l_ret'] = 0.0
pf[['l_ret']] = pf[['l_ret']].astype('float')
pf.to_csv('panel_fin.csv')
pf = pf.set_index(['Entity', 'Quarter'])
pf
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/computation/expressions.py:68: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return op(a, b)
#                 Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 accyearquarter  \
# Entity Quarter
# 1.0    1.0               0           0.0             0.0         1987Q2
#        2.0               1           1.0             1.0         1987Q3
#        3.0               2           2.0             2.0         1987Q4
#        4.0               3           3.0             3.0         1988Q1
#        5.0               4           4.0             4.0         1988Q2
# ...                    ...           ...             ...            ...
# 868.0  90.0          33126       33126.0         33126.0         2009Q3
#        91.0          33127       33127.0         33127.0         2009Q4
#        92.0          33128       33128.0         33128.0         2010Q1
# ...

# %%
from linearmodels.panel import PooledOLS
from linearmodels.panel import PooledOLS
import statsmodels.api as sm
pf = pd.read_csv('./panel_fin.csv')
pf = pf.set_index(['Entity', 'Quarter'])

exog_vars = ['l_ret','l_btm','l_e_p']
exog = sm.add_constant(pf[exog_vars])
mod = PooledOLS(pf.ret, exog)
pooled_res = mod.fit()
print(pooled_res)
# Out:
#                           PooledOLS Estimation Summary
# ...
# Dep. Variable:                    ret   R-squared:                        0.0348
# Estimator:                  PooledOLS   R-squared (Between):              0.0328
# No. Observations:               33131   R-squared (Within):               0.0328
# Date:                Sat, Nov 28 2020   R-squared (Overall):              0.0348
# Time:                        17:50:23   Log-likelihood                 1.335e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      397.94
# Entities:                         867   P-value                           0.0000
# Avg Obs:                       38.213   Distribution:                 F(3,33127)
# Min Obs:                       1.0000
# Max Obs:                       388.00   F-statistic (robust):             397.94
#                                         P-value                           0.0000
# ...
